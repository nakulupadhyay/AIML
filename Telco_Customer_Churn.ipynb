# %%
pip install ydata_profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 74.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 44.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
# /tmp/ipykernel_3009/2829373970.py:2: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
df=pd.read_csv("/content/Titanic-Dataset.csv")

# %%
profile=ProfileReport(df,title='dataset profiling test titanic',explorative=True)

# %%
profile.to_file("tatanic_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df2 = pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.xls")

# %%
profile2=ProfileReport(df2,title='dataset profiling test',explorative=True)

# %%
profile2.to_file("Telco_Customer_Churn.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# TASK 1

# %%
df2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df2['Churn_Flag'] = df2['Churn'].map({'Yes': 1, 'No': 0})

# %%
tenure_churn = df2.groupby('tenure')['Churn_Flag'].mean().reset_index()
tenure_churn.columns = ['Month_Number', 'Churn_Rate']

# %%
highest = tenure_churn.loc[tenure_churn['Churn_Rate'].idxmax()]

highest
# Out:
# Month_Number    1.000000
# Churn_Rate      0.619902
# Name: 1, dtype: float64

# %%
df2['tenure_group'] = pd.cut(df2['tenure'], bins=[0, 12, 24, float('inf')], labels=['0-12', '12-24', '>24'])

# %%
result = df2.groupby('tenure_group')['Churn_Flag'].mean()

result
# Out:
# /tmp/ipykernel_3009/3477512480.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   result = df2.groupby('tenure_group')['Churn_Flag'].mean()
# tenure_group
# 0-12     0.476782
# 12-24    0.287109
# >24      0.140360
# Name: Churn_Flag, dtype: float64

# %%
tenure_churn = df2.groupby('tenure_group')['Churn_Flag'].mean()
tenure_churn
# Out:
# /tmp/ipykernel_3009/1506871978.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tenure_churn = df2.groupby('tenure_group')['Churn_Flag'].mean()
# tenure_group
# 0-12     0.476782
# 12-24    0.287109
# >24      0.140360
# Name: Churn_Flag, dtype: float64

# %%
df2.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
df2.groupby('Contract')['Churn_Flag'].mean()
# Out:
# Contract
# Month-to-month    0.427097
# One year          0.112695
# Two year          0.028319
# Name: Churn_Flag, dtype: float64

# %%
df2.groupby('InternetService')['Churn_Flag'].mean()
# Out:
# InternetService
# DSL            0.189591
# Fiber optic    0.418928
# No             0.074050
# Name: Churn_Flag, dtype: float64

# %%
df2.groupby('Contract')['Churn_Flag'].mean()
# Out:
# Contract
# Month-to-month    0.427097
# One year          0.112695
# Two year          0.028319
# Name: Churn_Flag, dtype: float64

# %% [markdown]
# TASK 2

# %%
df2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df2.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Out:
# 0        1
# 1       34
# 2        2
# 3       45
# 4        2
#         ..
# 7038    24
# 7039    72
# 7040    11
# 7041     4
# 7042    66
# Name: tenure, Length: 7043, dtype: int64

# %%
df2['Churn']=df2['Churn'].replace({"No":0,"Yes":1})
# Out:
# /tmp/ipykernel_3009/2614562307.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2['Churn']=df2['Churn'].replace({"No":0,"Yes":1})

# %%
df2.pivot_table("Churn",index=['gender','Contract'],aggfunc="mean")
# Out:
#                           Churn
# gender Contract
# Female Month-to-month  0.437403
#        One year        0.104457
#        Two year        0.026036
# Male   Month-to-month  0.416923
#        One year        0.120530
#        Two year        0.030588

# %%
df2['Churn']=df2['Churn'].replace({0:"No",1:"Yes"})

# %%
pd.crosstab(df2['Churn'],df2['gender'])
# Out:
# gender  Female  Male
# Churn
# No        2549  2625
# Yes        939   930

# %%
df2['MonthlyCharges'].agg(['average','max','min'])
# Out:
# average     64.761692
# max        118.750000
# min         18.250000
# Name: MonthlyCharges, dtype: float64

# %%
df2['Churn']=df2['Churn'].replace({"No":0,"Yes":1})
# Out:
# /tmp/ipykernel_3009/2614562307.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2['Churn']=df2['Churn'].replace({"No":0,"Yes":1})

# %%
risk_score=df2.groupby('customerID')['Churn'].mean()

# %%
risk_score
# Out:
# customerID
# 0002-ORFBO    0.0
# 0003-MKNFE    0.0
# 0004-TLHLJ    1.0
# 0011-IGKFF    1.0
# 0013-EXCHZ    1.0
#              ...
# 9987-LUTYD    0.0
# 9992-RRAMN    1.0
# 9992-UJOEL    0.0
# 9993-LHIEB    0.0
# 9995-HOTOH    0.0
# Name: Churn, Length: 7043, dtype: float64
